# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()

# %%
df = pd.read_csv("fcc-forum-pageviews.csv", parse_dates=['date'])
df.set_index('date')
# Clean data
df = df[(df['value'] >= df['value'].quantile(0.025)) &
        (df['value'] <= df['value'].quantile(0.975))]
months= ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']

# %%
df.set_index('date')
# Out:
#              value
# date
# 2016-05-19   19736
# 2016-05-26   18060
# 2016-05-27   19997
# 2016-05-28   19044
# 2016-05-29   20325
# ...            ...
# 2019-11-24  138875
# 2019-11-29  171584
# 2019-11-30  141161
# 2019-12-01  142918
# 2019-12-03  158549
#
# [1238 rows x 1 columns]

# %%
df = df[(df['value'] >= df['value'].quantile(0.025)) & (df['value'] <= df['value'].quantile(0.975))]
months= ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']

# %%
df
# Out:
#            date   value
# 39   2016-06-17   21691
# 40   2016-06-18   21681
# 42   2016-06-20   28508
# 43   2016-06-21   26805
# 47   2016-06-25   21923
# ...         ...     ...
# 1273 2019-11-03  130118
# 1279 2019-11-09  115642
# 1280 2019-11-10  117717
# 1286 2019-11-16  125634
# 1287 2019-11-17  131639
#
# [1176 rows x 2 columns]

# %%
df_box = df.copy()

# %%
df_box['month'] = df_box['date'].dt.month_name(locale='English')
df_box['year'] = df_box['date'].dt.year

# %%
df_box
# Out:
#            date   value     month  year
# 39   2016-06-17   21691      June  2016
# 40   2016-06-18   21681      June  2016
# 42   2016-06-20   28508      June  2016
# 43   2016-06-21   26805      June  2016
# 47   2016-06-25   21923      June  2016
# ...         ...     ...       ...   ...
# 1273 2019-11-03  130118  November  2019
# 1279 2019-11-09  115642  November  2019
# 1280 2019-11-10  117717  November  2019
# 1286 2019-11-16  125634  November  2019
# 1287 2019-11-17  131639  November  2019
#
# [1176 rows x 4 columns]

# %%
sns
# Out:
# <module 'seaborn' from 'C:\\Users\\vvk19\\miniconda3\\envs\\dataanalytics\\Lib\\site-packages\\seaborn\\__init__.py'>

# %%
fig, (ax1,ax2) = plt.subplots(1,2,figsize=(15,5))

# %%
ax1= sns.boxplot(x='year', y='value', hue_order='year', data= df_box)

# %%
ax2= sns.boxplot(x='month', y='value', hue_order='month', data= df_box)

# %%
sns.set_theme(style="ticks", palette="pastel")
fig, axes = plt.subplots(1,2)
axes[0] = sns.boxplot(x='year', y="value",hue_order="year", data=df_box,ax=axes[0])
axes[1] = sns.boxplot(x='month', y="value", hue_order="month", data=df_box, ax=axes[1])
